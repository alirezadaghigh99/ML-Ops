# %%
import datetime
import os
from typing import List
import tfx.v1 as tfx
import absl
import tensorflow_model_analysis as tfma
from tfx.components import CsvExampleGen
from tfx.components import Evaluator
from tfx.components import ExampleValidator
from tfx.components import Pusher
from tfx.components import SchemaGen
from tfx.components import StatisticsGen
from tfx.components import Trainer
from tfx.components import Transform

from tfx.components.trainer.executor import Executor
from tfx.dsl.components.base import executor_spec
from tfx.dsl.experimental import latest_blessed_model_resolver
from tfx.orchestration import data_types
from tfx.orchestration import metadata
from tfx.orchestration import pipeline
from tfx.dsl.components.common import resolver
from tfx.dsl.experimental import latest_artifacts_resolver
from tfx.proto import pusher_pb2, example_gen_pb2
from tfx.proto import trainer_pb2
from tfx.types import Channel
from tfx.types.standard_artifacts import Model
from tfx.types.standard_artifacts import ModelBlessing

import pandas as pd
# Out:
# 2022-02-26 15:12:30.147396: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-26 15:12:30.147428: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
_pipeline_root = './pipeline/'

# Directory of the raw data files
_data_root = './data/criteo/data4'

# Temporary directory
tempdir = './tempdir'

# %%
output = example_gen_pb2.Output(
        split_config=example_gen_pb2.SplitConfig(splits=[
            example_gen_pb2.SplitConfig.Split(name='train', hash_buckets=9),
            example_gen_pb2.SplitConfig.Split(name='eval', hash_buckets=3),
            example_gen_pb2.SplitConfig.Split(name='test', hash_buckets=1),

        ]))

    # Ingest the data through ExampleGen
example_gen = CsvExampleGen(input_base=_data_root, output_config=output)

# %%
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
context = InteractiveContext(pipeline_root=_pipeline_root)
# Out:
# WARNING:absl:InteractiveContext metadata_connection_config not provided: using SQLite ML Metadata database at ./pipeline/metadata.sqlite.

# %%
context.run(example_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: CsvExampleGen
#     execution_id: 237
#     outputs:
#         examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 512
#         type_id: 14
#         uri: "./pipeline/CsvExampleGen/examples/237"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "file_format"
#           value {
#             string_value: "tfrecords_gzip"
#           }
#         }
#         custom_properties {
#           key: "input_fingerprint"
#           value {
#             string_value: "split:single_split,num_files:1,total_bytes:82488405,xor_checksum:1645709898,sum_checksum:1645709898"
#           }
#         }
#         custom_properties {
#           key: "payload_format"
#           value {
#             string_value: "FORMAT_TF_EXAMPLE"
#           }
#         }
#         custom_properties {
#           key: "span"
#           value {
#             int_value: 0
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
# !ls data/criteo/data3
# Out:
# data-small.csv

# %%
statistics_gen = StatisticsGen(
        examples=example_gen.outputs['examples'])
context.run(statistics_gen)
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 238
#     outputs:
#         statistics: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 513
#         type_id: 16
#         uri: "./pipeline/StatisticsGen/statistics/238"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "statistics"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "StatisticsGen"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         base_type: STATISTICS
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
context.show(statistics_gen.outputs["statistics"])
# Out:
# <b>Artifact at ./pipeline/StatisticsGen/statistics/229</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'eval' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
# <div><b>'test' split:</b></div><br/>
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
schema_gen = SchemaGen(
    statistics=statistics_gen.outputs['statistics'], infer_feature_shape=True)
context.run(schema_gen)
# Out:
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 230
#     outputs:
#         schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 498
#         type_id: 18
#         uri: "./pipeline/SchemaGen/schema/230"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "SchemaGen"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
user_provided_schema_path = f'./pipeline/SchemaGen/schema/224/schema.pbtxt'

schema_gen = tfx.components.ImportSchemaGen(
            schema_file=user_provided_schema_path)
context.run(schema_gen)
# Out:
# ExecutionResult(
#     component_id: ImportSchemaGen
#     execution_id: 239
#     outputs:
#         schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 514
#         type_id: 18
#         uri: "./pipeline/ImportSchemaGen/schema/239"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "ImportSchemaGen"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
schema_gen.outputs['schema'].get()[0].uri
# Out:
# './pipeline/ImportSchemaGen/schema/232'

# %%
example_validator = ExampleValidator(
    statistics=statistics_gen.outputs['statistics'],
    schema=schema_gen.outputs['schema'])
context.run(example_validator)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 240
#     outputs:
#         anomalies: Channel(
#             type_name: ExampleAnomalies
#             artifacts: [Artifact(artifact: id: 515
#         type_id: 20
#         uri: "./pipeline/ExampleValidator/anomalies/240"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\", \"test\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "anomalies"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "ExampleValidator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 20
#         name: "ExampleAnomalies"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
context.show(example_validator.outputs['anomalies'])
# Out:
# <b>Artifact at ./pipeline/ExampleValidator/anomalies/240</b><br/><br/>
# <div><b>'train' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'eval' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>
# <div><b>'test' split:</b></div><br/>
# <h4 style="color:green;">No anomalies found.</h4>

# %%
utils = "utils.py"

# %%
# %%writefile {utils}
# import logging
# from typing import List
# import matplotlib.pyplot as plt
# from keras import backend as K
# import keras_tuner as kt
# import tfx.v1 as tfx
# import keras_tuner
# import tensorflow as tf
# import tensorflow_transform as tft
# import pprint
# # Features with string data types that will be converted to indices
# from tfx.components.trainer.fn_args_utils import DataAccessor, FnArgs
# from tfx_bsl.tfxio import dataset_options
#
# CATEGORICAL_FEATURE_KEYS = [
#     'product_age_group', 'product_id', 'product_title', 'user_id', 'device_type', 'audience_id', 'product_gender',
#     'product_brand', 'product_category(1)', 'product_category(2)', 'product_category(3)', 'product_category(4)',
#     'product_category(5)', 'product_category(6)', 'product_category(7)', 'product_country', 'partner_id'
# ]
#
# # Numerical features that are marked as continuous
# NUMERIC_FEATURE_KEYS = ['nb_clicks_1week']
#
# # Feature that can be grouped into buckets
#
#
# # Feature that the model will predict
# TIME_KEY = 'time_delay_for_conversion'
# SALE = 'Sale'
#
#
# # Utility function for renaming the feature
# def transformed_name(key):
#     key = key.replace('(', '')
#     key = key.replace(')', '')
#     return key
#
#
# _NUMERIC_FEATURE_KEYS = NUMERIC_FEATURE_KEYS
# _CATEGORICAL_FEATURE_KEYS = CATEGORICAL_FEATURE_KEYS
# _SALE = SALE
# _transformed_name = transformed_name
#
#
# # Define the transformations
# def preprocessing_fn(inputs):
#     """tf.transform's callback function for preprocessing inputs.
#     Args:
#         inputs: map from feature keys to raw not-yet-transformed features.
#     Returns:
#         Map from string feature key to transformed feature operations.
#     """
#     outputs = {}
#
#     # Scale these features to the range [0,1]
#     for key in _NUMERIC_FEATURE_KEYS:
#         outputs[_transformed_name(key)] = tft.scale_to_0_1(_fill_in_missing(inputs[key]))
#
#     # Bucketize these features
#     # for key in _SALE:
#     #     print(key)
#
#     #     pprint(_TIME_KEY)
#     # Convert strings to indices in a vocabulary
#     for key in _CATEGORICAL_FEATURE_KEYS:
#         outputs[_transformed_name(key)] = tft.compute_and_apply_vocabulary(
#             _fill_in_missing(inputs[key]),
#             num_oov_buckets=1,
#             vocab_filename=key)
#     # outputs[_transformed_name('time_delay_for_conversion')] = inputs['time_delay_for_conversion']
#     outputs['Sale'] = _fill_in_missing(inputs['Sale'])
#     # Convert the label strings to an index
#
#     return outputs
#
#
# _DENSE_FLOAT_FEATURE_KEYS = NUMERIC_FEATURE_KEYS
# _VOCAB_FEATURE_KEYS = CATEGORICAL_FEATURE_KEYS
# _VOCAB_SIZE = 40
# _VOCAB_SIZE = 1000
# _transformed_name = transformed_name
#
# # Count of out-of-vocab buckets in which unrecognized VOCAB_FEATURES are hashed.
# _OOV_SIZE = 10
# _LABEL_KEY = SALE
#
#
# def _fill_in_missing(x):
#     """Replace missing values in a SparseTensor.
#     Fills in missing values of `x` with '' or 0, and converts to a dense tensor.
#     Args:
#     x: A `SparseTensor` of rank 2.  Its dense shape should have size at most 1
#       in the second dimension.
#     Returns:
#     A rank 1 tensor where missing values of `x` have been filled in.
#     """
#     if not isinstance(x, tf.sparse.SparseTensor):
#         return x
#
#     default_value = '' if x.dtype == tf.string else 0
#     return tf.squeeze(
#       tf.sparse.to_dense(
#           tf.SparseTensor(x.indices, x.values, [x.dense_shape[0], 1]),
#           default_value),
#       axis=1)
#
#
# def _transformed_names(keys):
#     return [_transformed_name(key) for key in keys]
#
#
# def _get_tf_examples_serving_signature(model, tf_transform_output):
#     """Returns a serving signature that accepts `tensorflow.Example`."""
#
#     # We need to track the layers in the model in order to save it.
#     # TODO(b/162357359): Revise once the bug is resolved.
#     model.tft_layer_inference = tf_transform_output.transform_features_layer()
#
#     @tf.function(input_signature=[
#         tf.TensorSpec(shape=[None], dtype=tf.string, name='examples')
#     ])
#     def serve_tf_examples_fn(serialized_tf_example):
#         """Returns the output to be used in the serving signature."""
#         raw_feature_spec = tf_transform_output.raw_feature_spec()
#         # Remove label feature since these will not be present at serving time.
#         raw_feature_spec.pop(_LABEL_KEY)
#         raw_features = tf.io.parse_example(serialized_tf_example, raw_feature_spec)
#         transformed_features = model.tft_layer_inference(raw_features)
#         logging.info('serve_transformed_features = %s', transformed_features)
#
#         outputs = model(transformed_features)
#         # reverse-lookup (opposite of transform.py).
#         return {'outputs': outputs}
#
#     return serve_tf_examples_fn
#
#
# def _get_transform_features_signature(model, tf_transform_output):
#     """Returns a serving signature that applies tf.Transform to features."""
#
#
#     model.tft_layer_eval = tf_transform_output.transform_features_layer()
#
#     @tf.function(input_signature=[
#         tf.TensorSpec(shape=[None], dtype=tf.string, name='examples')
#     ])
#     def transform_features_fn(serialized_tf_example):
#         """Returns the transformed_features to be fed as input to evaluator."""
#         raw_feature_spec = tf_transform_output.raw_feature_spec()
#         raw_features = tf.io.parse_example(serialized_tf_example, raw_feature_spec)
#         transformed_features = model.tft_layer_eval(raw_features)
#         logging.info('eval_transformed_features = %s', transformed_features)
#         return transformed_features
#
#     return transform_features_fn
#
# def _gzip_reader_fn(filenames):
#   '''Load compressed dataset
#   '''
#
#   # Load the dataset. Specify the compression type since it is saved as `.gz`
#   return tf.data.TFRecordDataset(filenames, compression_type='GZIP')
#
# def input_gen(file_pattern,
#               tf_transform_output,
#               num_epochs=None,
#               is_train = True,
#               batch_size=32) -> tf.data.Dataset:
#     '''Create batches of features and labels from TF Records
#
#     Returns:
#     A dataset of dict elements, (or a tuple of dict elements and label).
#     Each dict maps feature keys to Tensor or SparseTensor objects.
#     '''
#     transformed_feature_spec = (
#       tf_transform_output.transformed_feature_spec().copy())
#     print('salammmm ', transformed_feature_spec)
#     if is_train:
#         dataset = tf.data.experimental.make_batched_features_dataset(
#             file_pattern=file_pattern,
#             batch_size=batch_size,
#             features=transformed_feature_spec,
#             reader=_gzip_reader_fn,
#             num_epochs=num_epochs,
#             label_key=_LABEL_KEY)
#     else:
#         dataset = tf.data.experimental.make_batched_features_dataset(
#             file_pattern=file_pattern,
#             batch_size=batch_size,
#             features=transformed_feature_spec,
#             reader=_gzip_reader_fn,
#             num_epochs=num_epochs,
#             )
#
#
#     return dataset
#
#
# # def _input_fn(file_pattern: List[str],
# #               data_accessor: DataAccessor,
# #               tf_transform_output: tft.TFTransformOutput,
# #               batch_size: int = 200) -> tf.data.Dataset:
# #     """Generates features and label for tuning/training.
# #     Args:
# #       file_pattern: List of paths or patterns of input tfrecord files.
# #       data_accessor: DataAccessor for converting input to RecordBatch.
# #       tf_transform_output: A TFTransformOutput.
# #       batch_size: representing the number of consecutive elements of returned
# #         dataset to combine in a single batch
# #     Returns:
# #       A dataset that contains (features, indices) tuple where features is a
# #         dictionary of Tensors, and indices is a single Tensor of label indices.
# #     """
# #     return data_accessor.tf_dataset_factory(
# #         file_pattern,
# #         dataset_options.TensorFlowDatasetOptions(
# #             batch_size=batch_size, label_key=(_LABEL_KEY)),
# #         tf_transform_output.transformed_metadata.schema).repeat()
#
# def _build_keras_model_soft(hparams: keras_tuner.HyperParameters, base_model=None):
#     inputs = [tf.keras.layers.Input(shape=(1,), name=f) for f in _transformed_names(_DENSE_FLOAT_FEATURE_KEYS)]
#     inputs += [tf.keras.layers.Input(shape=(1,), name=f) for f in _transformed_names(_CATEGORICAL_FEATURE_KEYS)]
#     d = tf.keras.layers.concatenate(inputs)
#     d = tf.keras.layers.Dense(8, activation='relu')(d)
#     d = tf.keras.layers.Dense(8, activation='relu')(d)
#     outputs = tf.keras.layers.Dense(
#         1, activation='sigmoid')(d)
#     outputs = tf.squeeze(outputs, -1)
#
#     model = tf.keras.Model(inputs=inputs, outputs=outputs)
#     model.compile(
#       optimizer=tf.keras.optimizers.Adam(1e-2),
#       loss="binary_crossentropy",
#       metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.FalseNegatives()])
#     print(model.summary())
#
#     return model
# def _build_keras_model(hparams: keras_tuner.HyperParameters, base_model=None) -> tf.keras.Model:
#
#
#     hidden_units = [20
#         , 15
#         , 10, 5
#                    ]
#     real_valued_columns = [
#         tf.feature_column.numeric_column(key, shape=())
#         for key in _transformed_names(_DENSE_FLOAT_FEATURE_KEYS)
#     ]
#     categorical_columns = [
#         tf.feature_column.categorical_column_with_identity(
#             key, num_buckets=_VOCAB_SIZE + 1, default_value=0)
#         for key in _transformed_names(_VOCAB_FEATURE_KEYS)
#     ]
#
#     indicator_column = [
#         tf.feature_column.indicator_column(categorical_column)
#         for categorical_column in categorical_columns
#     ]
#
#     model = _wide_and_deep_classifier(
#         wide_columns=real_valued_columns,
#         deep_columns=indicator_column,
#         dnn_hidden_units=int(hparams.get('num_layers')) or [20, 15, 10, 5], lr=0.001, base_model=base_model)
#     return model
#
#
# def _wide_and_deep_classifier(wide_columns, deep_columns, dnn_hidden_units, lr, base_model = None):
#     """Build a simple keras wide and deep model.
#
#    Returns:
#      A Wide and Deep Keras model
#    """
#
#
#
#     input_layers = {
#         colname: tf.keras.layers.Input(name=colname, shape=(), dtype=tf.float32)
#         for colname in (_DENSE_FLOAT_FEATURE_KEYS)
#     }
#
#     input_layers.update({
#         colname: tf.keras.layers.Input(name=colname, shape=(), dtype='int32')
#         for colname in _transformed_names(_VOCAB_FEATURE_KEYS)
#     })
#
#
#     if True:
#         if base_model:
#             base_model.trainable = True
#             inp = base_model.input                                           # input placeholder
#             outputs = [base_model.layers[-5].output]          # all layer outputs
#             functors = [K.function([inp], [out]) for out in outputs]
# #             deep = functors[0](input_layers)[0]
#
#
#             deep = [func(input_layers) for func in functors][0][0]
#             deep = tf.keras.layers.Dense(32)(deep)
#             deep = tf.keras.layers.BatchNormalization()(deep)
#             deep = tf.keras.layers.ReLU()(deep)
#             deep = tf.keras.layers.Dropout(0.3)(deep)
#             print("salam", deep)
#         else:
#             print("sajlam")
#             deep = tf.keras.layers.DenseFeatures(deep_columns)(input_layers)
#             for numnodes in [ 32,16]:
#                 deep = tf.keras.layers.Dense(numnodes)(deep)
#                 deep = tf.keras.layers.Dropout(0.3)(deep)
#
#         wide = tf.keras.layers.DenseFeatures(wide_columns)(input_layers)
#
#         output = tf.keras.layers.Dense(
#             1, activation='sigmoid')(
#             tf.keras.layers.concatenate([deep, wide]))
#         output = tf.squeeze(output, -1)
#     else:
#         wide = tf.keras.layers.BatchNormalization()(input_layers)
#         deep = tf.keras.layers.DenseFeatures(deep_columns)(input_layers)
#         for units in [64, 32, 16]:
#             deep = tf.keras.layers.Dense(units)(deep)
#             deep = tf.keras.layers.BatchNormalization()(deep)
#             deep = tf.keras.layers.ReLU()(deep)
#             deep = tf.keras.layers.Dropout(0.3)(deep)
#         merged = tf.keras.layers.concatenate([wide, deep])
#         output = tf.keras.layers.Dense(units=2, activation="softmax")(merged)
#
#     model = tf.keras.Model(input_layers, output)
#     print(model.layers)
#     model.compile(
#         loss='binary_crossentropy',
#         optimizer=tf.keras.optimizers.Adam(lr=0.0001),
#         metrics=[tf.keras.metrics.AUC(), tf.keras.metrics.FalseNegatives()])
#     model.summary(print_fn=logging.info)
#     print(model.summary())
#     return model
#
#
# def create_model_inputs():
#     inputs = {}
#     for feature_name in _DENSE_FLOAT_FEATURE_KEYS:
#         inputs[feature_name] = tf.keras.layers.Input(
#                 name=feature_name, shape=(), dtype=tf.float32
#             )
#     for feature_name in CATEGORICAL_FEATURE_KEYS:
#         inputs[feature_name] = tf.keras.layers.Input(
#                 name=feature_name, shape=(), dtype=tf.string
#             )
#     return inputs
#
#
# def _get_hyperparameters() -> keras_tuner.HyperParameters:
#     """Returns hyperparameters for building Keras model."""
#     hp = keras_tuner.HyperParameters()
#     # Defines search space.
#     hp.Choice('learning_rate', [1e-2, 1e-3], default=1e-2)
#     hp.Int('num_layers', 3, 6, default=4)
#     return hp
#
#
# def tuner_fn(fn_args: FnArgs) -> tfx.components.TunerFnResult:
#     """Build the tuner using the KerasTuner API.
#     Args:
#     fn_args: Holds args as name/value pairs.
#       - working_dir: working dir for tuning.
#       - train_files: List of file paths containing training tf.Example data.
#       - eval_files: List of file paths containing eval tf.Example data.
#       - train_steps: number of train steps.
#       - eval_steps: number of eval steps.
#       - schema_path: optional schema of the input data.
#       - transform_graph_path: optional transform graph produced by TFT.
#     Returns:
#     A namedtuple contains the following:
#       - tuner: A BaseTuner that will be used for tuning.
#       - fit_kwargs: Args to pass to tuner's run_trial function for fitting the
#                     model , e.g., the training and validation dataset. Required
#                     args depend on the above tuner's implementation.
#     """
#
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_output)
#
#     tuner = kt.BayesianOptimization(
#     _build_keras_model,
#
#     objective=kt.Objective("val_loss", direction="min"),
#     max_trials=12,
#     num_initial_points=5,
#     alpha=0.0001,
#     beta=2.6,
#     seed=None,
#     hyperparameters=_get_hyperparameters(),
#     tune_new_entries=True,
#     allow_new_entries=True,
#     overwrite=True
# )
#
#     transform_graph = tft.TFTransformOutput(fn_args.transform_graph_path)
#
#     train_dataset = input_gen(
#       fn_args.train_files,
#       transform_graph,
#       4)
#
#     eval_dataset = input_gen(
#       fn_args.eval_files,
#       transform_graph,
#       1)
#     return tfx.components.TunerFnResult(
#       tuner=tuner,
#       fit_kwargs={
#           'x': train_dataset,
#           'validation_data': eval_dataset,
#           'steps_per_epoch': fn_args.train_steps,
#           'validation_steps': fn_args.eval_steps
#       })
#
#
# def run_fn(fn_args: FnArgs):
#     """Train the model based on given args.
#     Args:
#       fn_args: Holds args used to train the model as name/value pairs.
#     """
#     # Number of nodes in the first layer of the DNN
#     first_dnn_layer_size = 100
#     num_dnn_layers = 4
#     dnn_decay_factor = 0.7
#
#     tf_transform_output = tft.TFTransformOutput(fn_args.transform_output)
#
#     train_dataset = input_gen(fn_args.train_files,
#                               tf_transform_output, 4)
#     eval_dataset = input_gen(fn_args.eval_files,
#                              tf_transform_output, 1)
#
#     mirrored_strategy = tf.distribute.MirroredStrategy()
#     if fn_args.hyperparameters:
#         hparams = keras_tuner.HyperParameters.from_config(fn_args.hyperparameters)
#     else:
#     # _build_keras_model.
#         hparams = _get_hyperparameters()
#     if not fn_args.base_model:
#         with mirrored_strategy.scope():
#             model = _build_keras_model(
#                 # Construct layers sizes with exponetial decay
#                     hparams = hparams
#             )
#     else:
#         model_dir = f"./pipeline/Trainer/model/196/Format-Serving"
#         new_model = tf.keras.models.load_model(model_dir)
#         model = _build_keras_model(
#                 # Construct layers sizes with exponetial decay
#                 hparams=hparams, base_model=new_model)
#
#     # Write logs to path
#     tensorboard_callback = tf.keras.callbacks.TensorBoard(
#         log_dir=fn_args.model_run_dir, update_freq='batch')
#
#     history = model.fit(
#         train_dataset,
#         batch_size=32,
#         validation_data=eval_dataset,
#          epochs=25,
#         validation_steps=50,
#         callbacks=[tensorboard_callback])
#
#     plt.plot(history.history['loss'])
#     plt.plot(history.history['val_loss'])
#     plt.title('model loss')
#     plt.ylabel('loss')
#     plt.xlabel('epoch')
#     plt.legend(['train', 'val'], loc='upper left')
#     plt.show()
#
#     signatures = {
#         'serving_default':
#             _get_tf_examples_serving_signature(model, tf_transform_output),
#         'transform_features':
#             _get_transform_features_signature(model, tf_transform_output),
#
#     }
#     model.save(fn_args.serving_model_dir, save_format='tf', signatures=signatures)
# Out:
# Overwriting utils.py

# %%
transform = Transform(
    examples=example_gen.outputs['examples'],
    schema=schema_gen.outputs['schema'],
    module_file=utils)
context.run(transform)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying utils.py -> build/lib
# copying pipeline.py -> build/lib
# installing to /tmp/tmp_cv0clql
# running install
# running install_lib
# copying build/lib/utils.py -> /tmp/tmp_cv0clql
# copying build/lib/pipeline.py -> /tmp/tmp_cv0clql
# running install_egg_info
# running egg_info
# creating tfx_user_code_Transform.egg-info
# writing tfx_user_code_Transform.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Transform.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Transform.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Transform.egg-info/SOURCES.txt'
# Copying tfx_user_code_Transform.egg-info to /tmp/tmp_cv0clql/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3.7.egg-info
# running install_scripts
# creating /tmp/tmp_cv0clql/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/WHEEL
# creating '/tmp/tmpayw43dax/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl' and adding '/tmp/tmp_cv0clql' to it
# adding 'pipeline.py'
# adding 'utils.py'
# adding 'tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/METADATA'
# adding 'tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/WHEEL'
# adding 'tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/top_level.txt'
# adding 'tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/RECORD'
# removing /tmp/tmp_cv0clql
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/alireza/Desktop/MLOps/env/bin/python -m pip install --upgrade pip' command.
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/alireza/Desktop/MLOps/env/bin/python -m pip install --upgrade pip' command.
# Processing ./pipeline/_wheels/tfx_user_code_Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl
# Installing collected packages: tfx-user-code-Transform
# Successfully installed tfx-user-code-Transform-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/alireza/Desktop/MLOps/env/bin/python -m pip install --upgrade pip' command.
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_8/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_9/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_10/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_11/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_12/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_13/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_14/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_15/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_16/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_1/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_2/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_3/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_4/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_5/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_6/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_7/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_8/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_9/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_10/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_11/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_12/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_13/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_14/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_15/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:absl:Tables initialized inside a tf.function  will be re-initialized on every invocation of the function. This  re-initialization can have significant impact on performance. Consider lifting  them out of the graph context using  `tf.init_scope`.: compute_and_apply_vocabulary_16/apply_vocab/text_file_init/InitializeTableFromTextFileV2
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType], int] instead.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# INFO:tensorflow:Assets written to: ./pipeline/Transform/transform_graph/241/.temp_path/tftransform_tmp/ed22ce1dfd864ab1b9e80448c3e4b75a/assets
# INFO:tensorflow:Assets written to: ./pipeline/Transform/transform_graph/241/.temp_path/tftransform_tmp/ed22ce1dfd864ab1b9e80448c3e4b75a/assets
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:Assets written to: ./pipeline/Transform/transform_graph/241/.temp_path/tftransform_tmp/8f13f43893fb47029082621e16dd9f6f/assets
# INFO:tensorflow:Assets written to: ./pipeline/Transform/transform_graph/241/.temp_path/tftransform_tmp/8f13f43893fb47029082621e16dd9f6f/assets
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# Exception in thread Thread-2477:
# Traceback (most recent call last):
#   File "/home/alireza/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/apache_beam/runners/worker/data_plane.py", line 208, in run
#     self._function(*self._args, **self._kwargs)
#   File "/home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/apache_beam/runners/worker/sdk_worker.py", line 539, in shutdown_inactive_bundle_processors
#     for descriptor_id, last_access_time in self.last_access_times.items():
# RuntimeError: dictionary changed size during iteration
# ExecutionResult(
#     component_id: Transform
#     execution_id: 241
#     outputs:
#         transform_graph: Channel(
#             type_name: TransformGraph
#             artifacts: [Artifact(artifact: id: 516
#         type_id: 22
#         uri: "./pipeline/Transform/transform_graph/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transform_graph"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 22
#         name: "TransformGraph"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         transformed_examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 517
#         type_id: 14
#         uri: "./pipeline/Transform/transformed_examples/241"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"eval\", \"test\", \"train\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transformed_examples"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         base_type: DATASET
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         updated_analyzer_cache: Channel(
#             type_name: TransformCache
#             artifacts: [Artifact(artifact: id: 518
#         type_id: 23
#         uri: "./pipeline/Transform/updated_analyzer_cache/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "updated_analyzer_cache"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 23
#         name: "TransformCache"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 519
#         type_id: 18
#         uri: "./pipeline/Transform/pre_transform_schema/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 520
#         type_id: 16
#         uri: "./pipeline/Transform/pre_transform_stats/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         base_type: STATISTICS
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 521
#         type_id: 18
#         uri: "./pipeline/Transform/post_transform_schema/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 522
#         type_id: 16
#         uri: "./pipeline/Transform/post_transform_stats/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         base_type: STATISTICS
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_anomalies: Channel(
#             type_name: ExampleAnomalies
#             artifacts: [Artifact(artifact: id: 523
#         type_id: 20
#         uri: "./pipeline/Transform/post_transform_anomalies/241"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_anomalies"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 20
#         name: "ExampleAnomalies"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
tuner = tfx.components.Tuner(
       module_file=utils,
        examples=transform.outputs['transformed_examples'],
        transform_graph=transform.outputs['transform_graph'],
        schema=schema_gen.outputs['schema'],
        train_args=trainer_pb2.TrainArgs(num_steps=30),
#         base_model= model,
        
        eval_args=trainer_pb2.EvalArgs(num_steps=10))
context.run(tuner)
# Out:
# Trial 12 Complete [00h 00m 03s]
# val_loss: 0.3191511332988739
#
# Best val_loss So Far: 0.2365659475326538
# Total elapsed time: 00h 01m 00s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='val_loss', direction='min')
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 3
# Score: 0.2365659475326538
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 6
# Score: 0.25339949131011963
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 6
# Score: 0.26966673135757446
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 6
# Score: 0.30361872911453247
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 3
# Score: 0.30646079778671265
# Trial summary
# Hyperparameters:
# learning_rate: 0.001
# num_layers: 3
# Score: 0.30663374066352844
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 5
# Score: 0.3081333637237549
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 6
# Score: 0.3191511332988739
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 3
# Score: 0.3198363184928894
# Trial summary
# Hyperparameters:
# learning_rate: 0.01
# num_layers: 4
# Score: 0.33231061697006226
# ExecutionResult(
#     component_id: Tuner
#     execution_id: 187
#     outputs:
#         best_hyperparameters: Channel(
#             type_name: HyperParameters
#             artifacts: [Artifact(artifact: id: 411
#         type_id: 28
#         uri: "./pipeline/Tuner/best_hyperparameters/187"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "best_hyperparameters"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Tuner"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 28
#         name: "HyperParameters"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
trainer = Trainer(
        module_file=utils,
        examples=transform.outputs['transformed_examples'],
        transform_graph=transform.outputs['transform_graph'],
        schema=schema_gen.outputs['schema'],
#         hyperparameters=(tuner.outputs['best_hyperparameters']
#                        if True else None),
        train_args=trainer_pb2.TrainArgs(num_steps=6000),
        base_model= model,
        
        eval_args=trainer_pb2.EvalArgs(num_steps=600))

context.run(trainer)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying utils.py -> build/lib
# copying pipeline.py -> build/lib
# installing to /tmp/tmp2zad68ny
# running install
# running install_lib
# copying build/lib/utils.py -> /tmp/tmp2zad68ny
# copying build/lib/pipeline.py -> /tmp/tmp2zad68ny
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmp2zad68ny/tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3.7.egg-info
# running install_scripts
# creating /tmp/tmp2zad68ny/tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/WHEEL
# creating '/tmp/tmpgdgc3eqa/tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl' and adding '/tmp/tmp2zad68ny' to it
# adding 'pipeline.py'
# adding 'utils.py'
# adding 'tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183.dist-info/RECORD'
# removing /tmp/tmp2zad68ny
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipeline/_wheels/tfx_user_code_Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+5d0df83ad398d00682f5e64d727642a4bb7dd139f0c579eb4c826a733622f183
# salammmm  {'Sale': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'audience_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'device_type': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'nb_clicks_1week': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'partner_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_age_group': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_brand': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category1': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category2': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category3': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category4': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category5': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category6': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category7': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_country': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_gender': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_title': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None), 'user_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None)}
# salammmm  {'Sale': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'audience_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'device_type': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'nb_clicks_1week': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'partner_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_age_group': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_brand': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category1': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category2': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category3': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category4': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category5': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category6': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category7': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_country': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_gender': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_title': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None), 'user_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None)}
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/alireza/Desktop/MLOps/env/bin/python -m pip install --upgrade pip' command.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa40ec4f7b8> and <keras.engine.input_layer.InputLayer object at 0x7fa446d1d048>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa40ec4f7b8> and <keras.engine.input_layer.InputLayer object at 0x7fa446d1d048>).
# salam KerasTensor(type_spec=TensorSpec(shape=(None, 17), dtype=tf.float32, name=None), name='re_lu_1/Relu:0', description="created by layer 're_lu_1'")
# [<keras.engine.input_layer.InputLayer object at 0x7fa421b17c18>, <keras.engine.input_layer.InputLayer object at 0x7fa421b17d30>, <keras.engine.input_layer.InputLayer object at 0x7fa423427cf8>, <keras.engine.input_layer.InputLayer object at 0x7fa4233df908>, <keras.engine.input_layer.InputLayer object at 0x7fa4233a8c50>, <keras.engine.input_layer.InputLayer object at 0x7fa421b17438>, <keras.engine.input_layer.InputLayer object at 0x7fa421b19da0>, <keras.engine.input_layer.InputLayer object at 0x7fa421b19c88>, <keras.engine.input_layer.InputLayer object at 0x7fa421b19a58>, <keras.engine.input_layer.InputLayer object at 0x7fa421b19908>, <keras.engine.input_layer.InputLayer object at 0x7fa421b192e8>, <keras.engine.input_layer.InputLayer object at 0x7fa421b13be0>, <keras.engine.input_layer.InputLayer object at 0x7fa421b13198>, <keras.engine.input_layer.InputLayer object at 0x7fa423399470>, <keras.engine.input_layer.InputLayer object at 0x7fa421b17828>, <keras.engine.input_layer.InputLayer object at 0x7fa4233a8908>, <keras.engine.input_layer.InputLayer object at 0x7fa421b1c4e0>, <keras.engine.input_layer.InputLayer object at 0x7fa421b1c860>, <keras.engine.functional.Functional object at 0x7fa445c534e0>, <keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7fa423427588>, <keras.layers.advanced_activations.ReLU object at 0x7fa43f7ad898>, <keras.feature_column.dense_features_v2.DenseFeatures object at 0x7fa43f7b7f60>, <keras.layers.merge.Concatenate object at 0x7fa43e920860>, <keras.layers.core.dense.Dense object at 0x7fa43e92a5f8>, <keras.layers.core.tf_op_layer.TFOpLambda object at 0x7fa43e92df60>]
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audience_id (InputLayer)       [(None,)]            0           []
#
#  device_type (InputLayer)       [(None,)]            0           []
#
#  nb_clicks_1week (InputLayer)   [(None,)]            0           []
#
#  partner_id (InputLayer)        [(None,)]            0           []
#
#  product_age_group (InputLayer)  [(None,)]           0           []
#
#  product_brand (InputLayer)     [(None,)]            0           []
#
#  product_category1 (InputLayer)  [(None,)]           0           []
#
#  product_category2 (InputLayer)  [(None,)]           0           []
#
#  product_category3 (InputLayer)  [(None,)]           0           []
#
#  product_category4 (InputLayer)  [(None,)]           0           []
#
#  product_category5 (InputLayer)  [(None,)]           0           []
#
#  product_category6 (InputLayer)  [(None,)]           0           []
#
#  product_category7 (InputLayer)  [(None,)]           0           []
#
#  product_country (InputLayer)   [(None,)]            0           []
#
#  product_gender (InputLayer)    [(None,)]            0           []
#
#  product_id (InputLayer)        [(None,)]            0           []
#
#  product_title (InputLayer)     [(None,)]            0           []
#
#  user_id (InputLayer)           [(None,)]            0           []
#
#  model_3 (Functional)           (None, 17)           545104      ['audience_id[0][0]',
#                                                                   'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 17)          68          ['model_3[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 17)           0           ['batch_normalization_1[0][0]']
#
#  dense_features_3 (DenseFeature  (None, 1)           0           ['audience_id[0][0]',
#  s)                                                               'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 18)           0           ['re_lu_1[0][0]',
#                                                                   'dense_features_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            19          ['concatenate_2[0][0]']
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None,)             0           ['dense_5[0][0]']
#  mbda)
#
# ==================================================================================================
# Total params: 545,191
# Trainable params: 53
# Non-trainable params: 545,138
# __________________________________________________________________________________________________
# None
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/25
# 17294/17294 [==============================] - 86s 5ms/step - loss: 0.3472 - auc_2: 0.6857 - false_negatives_2: 58143.0000 - val_loss: 0.2971 - val_auc_2: 0.7423 - val_false_negatives_2: 145.0000
# Epoch 2/25
# 17294/17294 [==============================] - 80s 5ms/step - loss: 0.2962 - auc_2: 0.7755 - false_negatives_2: 58553.0000 - val_loss: 0.2885 - val_auc_2: 0.7527 - val_false_negatives_2: 148.0000
# Epoch 3/25
# 17294/17294 [==============================] - 87s 5ms/step - loss: 0.2935 - auc_2: 0.7794 - false_negatives_2: 57613.0000 - val_loss: 0.2894 - val_auc_2: 0.7403 - val_false_negatives_2: 133.0000
# Epoch 4/25
# 17294/17294 [==============================] - 87s 5ms/step - loss: 0.2922 - auc_2: 0.7823 - false_negatives_2: 57177.0000 - val_loss: 0.2794 - val_auc_2: 0.7596 - val_false_negatives_2: 132.0000
# Epoch 5/25
# 17294/17294 [==============================] - 84s 5ms/step - loss: 0.2915 - auc_2: 0.7840 - false_negatives_2: 56965.0000 - val_loss: 0.3220 - val_auc_2: 0.7465 - val_false_negatives_2: 162.0000
# Epoch 6/25
# 17294/17294 [==============================] - 72s 4ms/step - loss: 0.2911 - auc_2: 0.7856 - false_negatives_2: 56891.0000 - val_loss: 0.2927 - val_auc_2: 0.7561 - val_false_negatives_2: 134.0000
# Epoch 7/25
# 17294/17294 [==============================] - 74s 4ms/step - loss: 0.2908 - auc_2: 0.7861 - false_negatives_2: 56802.0000 - val_loss: 0.2787 - val_auc_2: 0.7608 - val_false_negatives_2: 135.0000
# Epoch 8/25
# 17294/17294 [==============================] - 82s 5ms/step - loss: 0.2902 - auc_2: 0.7866 - false_negatives_2: 56726.0000 - val_loss: 0.2751 - val_auc_2: 0.7443 - val_false_negatives_2: 131.0000
# Epoch 9/25
# 17294/17294 [==============================] - 73s 4ms/step - loss: 0.2903 - auc_2: 0.7867 - false_negatives_2: 56833.0000 - val_loss: 0.2960 - val_auc_2: 0.7312 - val_false_negatives_2: 135.0000
# Epoch 10/25
# 17294/17294 [==============================] - 73s 4ms/step - loss: 0.2900 - auc_2: 0.7874 - false_negatives_2: 56655.0000 - val_loss: 0.3052 - val_auc_2: 0.7303 - val_false_negatives_2: 143.0000
# Epoch 11/25
# 17294/17294 [==============================] - 72s 4ms/step - loss: 0.2899 - auc_2: 0.7876 - false_negatives_2: 56751.0000 - val_loss: 0.3020 - val_auc_2: 0.7260 - val_false_negatives_2: 145.0000
# Epoch 12/25
# 17294/17294 [==============================] - 74s 4ms/step - loss: 0.2899 - auc_2: 0.7878 - false_negatives_2: 56716.0000 - val_loss: 0.2720 - val_auc_2: 0.7605 - val_false_negatives_2: 135.0000
# Epoch 13/25
# 17294/17294 [==============================] - 78s 4ms/step - loss: 0.2897 - auc_2: 0.7880 - false_negatives_2: 56685.0000 - val_loss: 0.2757 - val_auc_2: 0.7796 - val_false_negatives_2: 144.0000
# Epoch 14/25
# 17294/17294 [==============================] - 81s 5ms/step - loss: 0.2898 - auc_2: 0.7878 - false_negatives_2: 56711.0000 - val_loss: 0.2795 - val_auc_2: 0.7657 - val_false_negatives_2: 147.0000
# Epoch 15/25
# 17294/17294 [==============================] - 78s 5ms/step - loss: 0.2897 - auc_2: 0.7880 - false_negatives_2: 56695.0000 - val_loss: 0.2803 - val_auc_2: 0.7332 - val_false_negatives_2: 128.0000
# Epoch 16/25
# 17294/17294 [==============================] - 85s 5ms/step - loss: 0.2897 - auc_2: 0.7881 - false_negatives_2: 56916.0000 - val_loss: 0.3005 - val_auc_2: 0.7367 - val_false_negatives_2: 143.0000
# Epoch 17/25
# 17294/17294 [==============================] - 78s 4ms/step - loss: 0.2899 - auc_2: 0.7876 - false_negatives_2: 56821.0000 - val_loss: 0.2945 - val_auc_2: 0.7219 - val_false_negatives_2: 133.0000
# Epoch 18/25
# 17294/17294 [==============================] - 76s 4ms/step - loss: 0.2894 - auc_2: 0.7885 - false_negatives_2: 56758.0000 - val_loss: 0.2949 - val_auc_2: 0.7250 - val_false_negatives_2: 143.0000
# Epoch 19/25
# 17294/17294 [==============================] - 91s 5ms/step - loss: 0.2896 - auc_2: 0.7881 - false_negatives_2: 56814.0000 - val_loss: 0.3261 - val_auc_2: 0.7090 - val_false_negatives_2: 152.0000
# Epoch 20/25
# 17294/17294 [==============================] - 81s 5ms/step - loss: 0.2895 - auc_2: 0.7888 - false_negatives_2: 56809.0000 - val_loss: 0.3102 - val_auc_2: 0.7095 - val_false_negatives_2: 140.0000
# Epoch 21/25
# 17294/17294 [==============================] - 85s 5ms/step - loss: 0.2893 - auc_2: 0.7886 - false_negatives_2: 56760.0000 - val_loss: 0.2947 - val_auc_2: 0.7365 - val_false_negatives_2: 145.0000
# Epoch 22/25
# 17294/17294 [==============================] - 93s 5ms/step - loss: 0.2896 - auc_2: 0.7881 - false_negatives_2: 56840.0000 - val_loss: 0.3091 - val_auc_2: 0.7338 - val_false_negatives_2: 155.0000
# Epoch 23/25
# 17294/17294 [==============================] - 95s 5ms/step - loss: 0.2894 - auc_2: 0.7885 - false_negatives_2: 56850.0000 - val_loss: 0.2879 - val_auc_2: 0.7463 - val_false_negatives_2: 136.0000
# Epoch 24/25
# 17294/17294 [==============================] - 95s 5ms/step - loss: 0.2895 - auc_2: 0.7883 - false_negatives_2: 56807.0000 - val_loss: 0.2742 - val_auc_2: 0.7481 - val_false_negatives_2: 137.0000
# Epoch 25/25
# 17294/17294 [==============================] - 92s 5ms/step - loss: 0.2894 - auc_2: 0.7886 - false_negatives_2: 56768.0000 - val_loss: 0.3021 - val_auc_2: 0.7236 - val_false_negatives_2: 139.0000
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:Assets written to: ./pipeline/Trainer/model/242/Format-Serving/assets
# INFO:tensorflow:Assets written to: ./pipeline/Trainer/model/242/Format-Serving/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 242
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: [Artifact(artifact: id: 524
#         type_id: 25
#         uri: "./pipeline/Trainer/model/242"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 25
#         name: "Model"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_run: Channel(
#             type_name: ModelRun
#             artifacts: [Artifact(artifact: id: 525
#         type_id: 26
#         uri: "./pipeline/Trainer/model_run/242"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model_run"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 26
#         name: "ModelRun"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
# model =  trainer.outputs['model']


trainer = Trainer(
        module_file=utils,
        examples=transform.outputs['transformed_examples'],
        transform_graph=transform.outputs['transform_graph'],
        schema=schema_gen.outputs['schema'],
#         hyperparameters=(tuner.outputs['best_hyperparameters']
#                        if True else None),
        train_args=trainer_pb2.TrainArgs(num_steps=6000),
#         base_model= model,
        
        eval_args=trainer_pb2.EvalArgs(num_steps=600))

context.run(trainer)
# Out:
# running bdist_wheel
# running build
# running build_py
# creating build
# creating build/lib
# copying utils.py -> build/lib
# copying pipeline.py -> build/lib
# installing to /tmp/tmp9ehs8xov
# running install
# running install_lib
# copying build/lib/utils.py -> /tmp/tmp9ehs8xov
# copying build/lib/pipeline.py -> /tmp/tmp9ehs8xov
# running install_egg_info
# running egg_info
# creating tfx_user_code_Trainer.egg-info
# writing tfx_user_code_Trainer.egg-info/PKG-INFO
# writing dependency_links to tfx_user_code_Trainer.egg-info/dependency_links.txt
# writing top-level names to tfx_user_code_Trainer.egg-info/top_level.txt
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# reading manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# writing manifest file 'tfx_user_code_Trainer.egg-info/SOURCES.txt'
# Copying tfx_user_code_Trainer.egg-info to /tmp/tmp9ehs8xov/tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f-py3.7.egg-info
# running install_scripts
# creating /tmp/tmp9ehs8xov/tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f.dist-info/WHEEL
# creating '/tmp/tmps_22ljlj/tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f-py3-none-any.whl' and adding '/tmp/tmp9ehs8xov' to it
# adding 'pipeline.py'
# adding 'utils.py'
# adding 'tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f.dist-info/METADATA'
# adding 'tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f.dist-info/WHEEL'
# adding 'tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f.dist-info/top_level.txt'
# adding 'tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f.dist-info/RECORD'
# removing /tmp/tmp9ehs8xov
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/setuptools/command/install.py:37: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   setuptools.SetuptoolsDeprecationWarning,
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# Processing ./pipeline/_wheels/tfx_user_code_Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f-py3-none-any.whl
# Installing collected packages: tfx-user-code-Trainer
# Successfully installed tfx-user-code-Trainer-0.0+e7db6bd1b6d42312cd1fa86f0ac4819867d083a6aa047bce28fc9e4f26caea3f
# salammmm  {'Sale': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'audience_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'device_type': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'nb_clicks_1week': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'partner_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_age_group': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_brand': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category1': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category2': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category3': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category4': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category5': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category6': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category7': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_country': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_gender': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_title': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None), 'user_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None)}
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/home/alireza/Desktop/MLOps/env/bin/python -m pip install --upgrade pip' command.
# salammmm  {'Sale': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'audience_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'device_type': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'nb_clicks_1week': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None), 'partner_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_age_group': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_brand': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category1': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category2': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category3': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category4': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category5': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category6': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_category7': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_country': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_gender': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None), 'product_title': FixedLenFeature(shape=[], dtype=tf.int64, default_value=None), 'user_id': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None)}
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# WARNING:tensorflow:There are non-GPU devices in `tf.distribute.Strategy`, not using nccl allreduce.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:CPU:0',)
# sajlam
# [<keras.engine.input_layer.InputLayer object at 0x7fa4232e8710>, <keras.engine.input_layer.InputLayer object at 0x7fa4232e8fd0>, <keras.engine.input_layer.InputLayer object at 0x7fa40d6856a0>, <keras.engine.input_layer.InputLayer object at 0x7fa40d3d0748>, <keras.engine.input_layer.InputLayer object at 0x7fa407988b00>, <keras.engine.input_layer.InputLayer object at 0x7fa40d835b38>, <keras.engine.input_layer.InputLayer object at 0x7fa40d4a57b8>, <keras.engine.input_layer.InputLayer object at 0x7fa40d4a5048>, <keras.engine.input_layer.InputLayer object at 0x7fa40d4a5898>, <keras.engine.input_layer.InputLayer object at 0x7fa40d4a5470>, <keras.engine.input_layer.InputLayer object at 0x7fa407c49c88>, <keras.engine.input_layer.InputLayer object at 0x7fa40d3d0d30>, <keras.engine.input_layer.InputLayer object at 0x7fa40d3d0550>, <keras.engine.input_layer.InputLayer object at 0x7fa40d3d0e48>, <keras.engine.input_layer.InputLayer object at 0x7fa4232e84e0>, <keras.engine.input_layer.InputLayer object at 0x7fa407988470>, <keras.engine.input_layer.InputLayer object at 0x7fa4079882b0>, <keras.engine.input_layer.InputLayer object at 0x7fa4232e89b0>, <keras.feature_column.dense_features_v2.DenseFeatures object at 0x7fa40d685dd8>, <keras.layers.core.dense.Dense object at 0x7fa40d460860>, <keras.layers.core.dropout.Dropout object at 0x7fa444adb5f8>, <keras.layers.core.dense.Dense object at 0x7fa4232db198>, <keras.layers.core.dropout.Dropout object at 0x7fa423479a58>, <keras.feature_column.dense_features_v2.DenseFeatures object at 0x7fa407a1c668>, <keras.layers.merge.Concatenate object at 0x7fa40c145cf8>, <keras.layers.core.dense.Dense object at 0x7fa407ce6240>, <keras.layers.core.tf_op_layer.TFOpLambda object at 0x7fa40c145c18>]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audience_id (InputLayer)       [(None,)]            0           []
#
#  device_type (InputLayer)       [(None,)]            0           []
#
#  nb_clicks_1week (InputLayer)   [(None,)]            0           []
#
#  partner_id (InputLayer)        [(None,)]            0           []
#
#  product_age_group (InputLayer)  [(None,)]           0           []
#
#  product_brand (InputLayer)     [(None,)]            0           []
#
#  product_category1 (InputLayer)  [(None,)]           0           []
#
#  product_category2 (InputLayer)  [(None,)]           0           []
#
#  product_category3 (InputLayer)  [(None,)]           0           []
#
#  product_category4 (InputLayer)  [(None,)]           0           []
#
#  product_category5 (InputLayer)  [(None,)]           0           []
#
#  product_category6 (InputLayer)  [(None,)]           0           []
#
#  product_category7 (InputLayer)  [(None,)]           0           []
#
#  product_country (InputLayer)   [(None,)]            0           []
#
#  product_gender (InputLayer)    [(None,)]            0           []
#
#  product_id (InputLayer)        [(None,)]            0           []
#
#  product_title (InputLayer)     [(None,)]            0           []
#
#  user_id (InputLayer)           [(None,)]            0           []
#
#  dense_features (DenseFeatures)  (None, 17017)       0           ['audience_id[0][0]',
#                                                                   'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  dense (Dense)                  (None, 32)           544576      ['dense_features[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 16)           528         ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['dense_1[0][0]']
#
#  dense_features_1 (DenseFeature  (None, 1)           0           ['audience_id[0][0]',
#  s)                                                               'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  concatenate (Concatenate)      (None, 17)           0           ['dropout_1[0][0]',
#                                                                   'dense_features_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            18          ['concatenate[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None,)             0           ['dense_2[0][0]']
#  da)
#
# ==================================================================================================
# Total params: 545,122
# Trainable params: 545,122
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 2022-02-26 15:25:04.364912: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 1/25
#   17289/Unknown - 135s 7ms/step - loss: 0.3134 - auc: 0.7280 - false_negatives: 59397.0000
# 2022-02-26 15:27:20.011270: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 138s 8ms/step - loss: 0.3134 - auc: 0.7280 - false_negatives: 59425.0000 - val_loss: 0.2803 - val_auc: 0.7620 - val_false_negatives: 150.0000
# Epoch 2/25
# 17294/17294 [==============================] - ETA: 0s - loss: 0.2965 - auc: 0.7724 - false_negatives: 57079.0000
# 2022-02-26 15:29:31.913868: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 129s 7ms/step - loss: 0.2965 - auc: 0.7724 - false_negatives: 57079.0000 - val_loss: 0.2966 - val_auc: 0.7412 - val_false_negatives: 147.0000
# Epoch 3/25
# 17287/17294 [============================>.] - ETA: 0s - loss: 0.2926 - auc: 0.7809 - false_negatives: 56560.0000
# 2022-02-26 15:31:42.129552: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 130s 8ms/step - loss: 0.2926 - auc: 0.7809 - false_negatives: 56593.0000 - val_loss: 0.2780 - val_auc: 0.7464 - val_false_negatives: 127.0000
# Epoch 4/25
# 17290/17294 [============================>.] - ETA: 0s - loss: 0.2906 - auc: 0.7851 - false_negatives: 56302.0000
# 2022-02-26 15:34:10.257541: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 148s 9ms/step - loss: 0.2906 - auc: 0.7851 - false_negatives: 56315.0000 - val_loss: 0.3068 - val_auc: 0.7116 - val_false_negatives: 148.0000
# Epoch 5/25
# 17293/17294 [============================>.] - ETA: 0s - loss: 0.2892 - auc: 0.7878 - false_negatives: 56251.0000
# 2022-02-26 15:36:42.098013: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 152s 9ms/step - loss: 0.2892 - auc: 0.7878 - false_negatives: 56255.0000 - val_loss: 0.2796 - val_auc: 0.7570 - val_false_negatives: 143.0000
# Epoch 6/25
# 17290/17294 [============================>.] - ETA: 0s - loss: 0.2885 - auc: 0.7892 - false_negatives: 56118.0000
# 2022-02-26 15:39:15.970080: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 154s 9ms/step - loss: 0.2885 - auc: 0.7892 - false_negatives: 56135.0000 - val_loss: 0.2683 - val_auc: 0.7596 - val_false_negatives: 130.0000
# Epoch 7/25
# 17291/17294 [============================>.] - ETA: 0s - loss: 0.2874 - auc: 0.7916 - false_negatives: 55972.0000
# 2022-02-26 15:41:43.167330: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 147s 9ms/step - loss: 0.2874 - auc: 0.7915 - false_negatives: 55980.0000 - val_loss: 0.2719 - val_auc: 0.7658 - val_false_negatives: 134.0000
# Epoch 8/25
# 17291/17294 [============================>.] - ETA: 0s - loss: 0.2872 - auc: 0.7920 - false_negatives: 56008.0000
# 2022-02-26 15:44:01.738473: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 138s 8ms/step - loss: 0.2872 - auc: 0.7920 - false_negatives: 56017.0000 - val_loss: 0.3018 - val_auc: 0.7305 - val_false_negatives: 142.0000
# Epoch 9/25
# 17292/17294 [============================>.] - ETA: 0s - loss: 0.2867 - auc: 0.7932 - false_negatives: 55976.0000
# 2022-02-26 15:46:15.018504: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 130s 7ms/step - loss: 0.2867 - auc: 0.7931 - false_negatives: 55983.0000 - val_loss: 0.2898 - val_auc: 0.7234 - val_false_negatives: 133.0000
# Epoch 10/25
# 17284/17294 [============================>.] - ETA: 0s - loss: 0.2862 - auc: 0.7940 - false_negatives: 55904.0000
# 2022-02-26 15:49:03.916323: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 156s 9ms/step - loss: 0.2862 - auc: 0.7940 - false_negatives: 55944.0000 - val_loss: 0.3009 - val_auc: 0.7445 - val_false_negatives: 150.0000
# Epoch 11/25
# 17286/17294 [============================>.] - ETA: 0s - loss: 0.2860 - auc: 0.7946 - false_negatives: 55845.0000
# 2022-02-26 15:51:14.371772: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 130s 8ms/step - loss: 0.2861 - auc: 0.7946 - false_negatives: 55885.0000 - val_loss: 0.3203 - val_auc: 0.7420 - val_false_negatives: 166.0000
# Epoch 12/25
# 17293/17294 [============================>.] - ETA: 0s - loss: 0.2856 - auc: 0.7953 - false_negatives: 55862.0000
# 2022-02-26 15:53:25.631016: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 132s 8ms/step - loss: 0.2856 - auc: 0.7953 - false_negatives: 55863.0000 - val_loss: 0.2960 - val_auc: 0.7449 - val_false_negatives: 149.0000
# Epoch 13/25
# 17291/17294 [============================>.] - ETA: 0s - loss: 0.2856 - auc: 0.7959 - false_negatives: 55864.0000
# 2022-02-26 15:55:24.286007: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 117s 7ms/step - loss: 0.2857 - auc: 0.7958 - false_negatives: 55875.0000 - val_loss: 0.2967 - val_auc: 0.7557 - val_false_negatives: 145.0000
# Epoch 14/25
# 17294/17294 [==============================] - ETA: 0s - loss: 0.2855 - auc: 0.7957 - false_negatives: 55833.0000
# 2022-02-26 15:57:31.070064: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 127s 7ms/step - loss: 0.2855 - auc: 0.7957 - false_negatives: 55833.0000 - val_loss: 0.3198 - val_auc: 0.7440 - val_false_negatives: 162.0000
# Epoch 15/25
# 17291/17294 [============================>.] - ETA: 0s - loss: 0.2851 - auc: 0.7966 - false_negatives: 55823.0000
# 2022-02-26 15:59:40.961183: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 130s 8ms/step - loss: 0.2851 - auc: 0.7966 - false_negatives: 55834.0000 - val_loss: 0.2807 - val_auc: 0.7444 - val_false_negatives: 140.0000
# Epoch 16/25
# 17288/17294 [============================>.] - ETA: 0s - loss: 0.2852 - auc: 0.7966 - false_negatives: 55842.0000
# 2022-02-26 16:02:00.796683: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 128s 7ms/step - loss: 0.2852 - auc: 0.7965 - false_negatives: 55863.0000 - val_loss: 0.2831 - val_auc: 0.7453 - val_false_negatives: 143.0000
# Epoch 17/25
# 17294/17294 [==============================] - ETA: 0s - loss: 0.2849 - auc: 0.7971 - false_negatives: 55751.0000
# 2022-02-26 16:03:51.508835: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 111s 6ms/step - loss: 0.2849 - auc: 0.7971 - false_negatives: 55751.0000 - val_loss: 0.2773 - val_auc: 0.7579 - val_false_negatives: 132.0000
# Epoch 18/25
# 17294/17294 [==============================] - 119s 7ms/step - loss: 0.2848 - auc: 0.7972 - false_negatives: 55815.0000 - val_loss: 0.3101 - val_auc: 0.7225 - val_false_negatives: 147.0000
# 2022-02-26 16:05:51.161343: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 19/25
# 17294/17294 [==============================] - 112s 6ms/step - loss: 0.2849 - auc: 0.7971 - false_negatives: 55770.0000 - val_loss: 0.2789 - val_auc: 0.7343 - val_false_negatives: 130.0000
# 2022-02-26 16:07:43.637104: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 20/25
# 17286/17294 [============================>.] - ETA: 0s - loss: 0.2848 - auc: 0.7975 - false_negatives: 55748.0000
# 2022-02-26 16:09:32.708926: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 109s 6ms/step - loss: 0.2848 - auc: 0.7975 - false_negatives: 55779.0000 - val_loss: 0.2910 - val_auc: 0.7437 - val_false_negatives: 138.0000
# Epoch 21/25
# 17294/17294 [==============================] - 109s 6ms/step - loss: 0.2846 - auc: 0.7978 - false_negatives: 55770.0000 - val_loss: 0.3078 - val_auc: 0.7313 - val_false_negatives: 148.0000
# 2022-02-26 16:11:22.027791: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# Epoch 22/25
# 17291/17294 [============================>.] - ETA: 0s - loss: 0.2845 - auc: 0.7982 - false_negatives: 55729.0000- ETA: 1s - loss: 0.2840 - auc
# 2022-02-26 16:13:26.619940: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 126s 7ms/step - loss: 0.2845 - auc: 0.7982 - false_negatives: 55742.0000 - val_loss: 0.2982 - val_auc: 0.7378 - val_false_negatives: 146.0000
# Epoch 23/25
# 17290/17294 [============================>.] - ETA: 0s - loss: 0.2845 - auc: 0.7984 - false_negatives: 55742.0000
# 2022-02-26 16:16:01.740649: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 154s 9ms/step - loss: 0.2844 - auc: 0.7984 - false_negatives: 55752.0000 - val_loss: 0.3127 - val_auc: 0.7312 - val_false_negatives: 148.0000
# Epoch 24/25
# 17293/17294 [============================>.] - ETA: 0s - loss: 0.2843 - auc: 0.7986 - false_negatives: 55742.0000
# 2022-02-26 16:18:09.653857: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 128s 7ms/step - loss: 0.2843 - auc: 0.7986 - false_negatives: 55745.0000 - val_loss: 0.3068 - val_auc: 0.7071 - val_false_negatives: 131.0000
# Epoch 25/25
# 17288/17294 [============================>.] - ETA: 0s - loss: 0.2843 - auc: 0.7985 - false_negatives: 55675.0000
# 2022-02-26 16:20:19.548381: W tensorflow/core/framework/dataset.cc:744] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 17294/17294 [==============================] - 130s 7ms/step - loss: 0.2843 - auc: 0.7985 - false_negatives: 55701.0000 - val_loss: 0.2765 - val_auc: 0.7746 - val_false_negatives: 139.0000
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:Assets written to: ./pipeline/Trainer/model/227/Format-Serving/assets
# INFO:tensorflow:Assets written to: ./pipeline/Trainer/model/227/Format-Serving/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 227
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: [Artifact(artifact: id: 494
#         type_id: 25
#         uri: "./pipeline/Trainer/model/227"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 25
#         name: "Model"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_run: Channel(
#             type_name: ModelRun
#             artifacts: [Artifact(artifact: id: 495
#         type_id: 26
#         uri: "./pipeline/Trainer/model_run/227"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model_run"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 26
#         name: "ModelRun"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
load_ext tensorboard
log_folder = 'logs'

# %%
# %tensorboard -- logdir={log_folder}
# Out:
# ERROR: Failed to launch TensorBoard (exited with 2).
# Contents of stderr:
# 2022-02-20 22:52:32.532524: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-20 22:52:32.532565: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# usage: tensorboard [-h] [--helpfull] [--logdir PATH] [--logdir_spec PATH_SPEC]
#                    [--host ADDR] [--bind_all] [--port PORT]
#                    [--reuse_port BOOL] [--load_fast {false,auto,true}]
#                    [--extra_data_server_flags EXTRA_DATA_SERVER_FLAGS]
#                    [--grpc_creds_type {local,ssl,ssl_dev}]
#                    [--grpc_data_provider PORT] [--purge_orphaned_data BOOL]
#                    [--db URI] [--db_import] [--inspect] [--version_tb]
#                    [--tag TAG] [--event_file PATH] [--path_prefix PATH]
#                    [--window_title TEXT] [--max_reload_threads COUNT]
#                    [--reload_interval SECONDS] [--reload_task TYPE]
#                    [--reload_multifile BOOL]
#                    [--reload_multifile_inactive_secs SECONDS]
#                    [--generic_data TYPE]
#                    [--samples_per_plugin SAMPLES_PER_PLUGIN]
#                    [--whatif-use-unsafe-custom-prediction YOUR_CUSTOM_PREDICT_FUNCTION.py]
#                    [--whatif-data-dir PATH]
#                    {serve,dev} ...
# tensorboard: error: invalid choice: '--' (choose from 'serve', 'dev')

# %%
df = pd.read_csv("data/criteo/data3/data3.csv")
# Out:
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
import tensorflow as tf
model_dir = f"./pipeline/Trainer/model/196/Format-Serving"
new_model1 = tf.keras.models.load_model(model_dir)
inp = new_model1.input                                           # input placeholder
outputs = [new_model1.layers[-5].output]
print(inp)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f9896efd630> and <keras.engine.input_layer.InputLayer object at 0x7f97bd56e048>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f9896efd630> and <keras.engine.input_layer.InputLayer object at 0x7f97bd56e048>).
# {'nb_clicks_1week': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'nb_clicks_1week')>, 'product_age_group': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_age_group')>, 'product_id': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_id')>, 'product_title': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_title')>, 'user_id': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'user_id')>, 'device_type': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'device_type')>, 'audience_id': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'audience_id')>, 'product_gender': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_gender')>, 'product_brand': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_brand')>, 'product_category1': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category1')>, 'product_category2': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category2')>, 'product_category3': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category3')>, 'product_category4': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category4')>, 'product_category5': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category5')>, 'product_category6': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category6')>, 'product_category7': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_category7')>, 'product_country': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'product_country')>, 'partner_id': <KerasTensor: shape=(None,) dtype=int32 (created by layer 'partner_id')>}

# %%
outputs = [new_model1.layers[-5].output]
outputs
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_features_7')>]

# %%
new_model1.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f98336e79b0>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336e7668>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336e81d0>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336e8828>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336e8e10>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336db128>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336db2e8>,
#  <keras.engine.input_layer.InputLayer at 0x7f98336dbd68>,
#  <keras.engine.input_layer.InputLayer at 0x7f9860c89208>,
#  <keras.engine.input_layer.InputLayer at 0x7f9860e63518>,
#  <keras.engine.input_layer.InputLayer at 0x7f9860e632e8>,
#  <keras.engine.input_layer.InputLayer at 0x7f9860924240>,
#  <keras.engine.input_layer.InputLayer at 0x7f98607d8a90>,
#  <keras.engine.input_layer.InputLayer at 0x7f986065e828>,
#  <keras.engine.input_layer.InputLayer at 0x7f986068f278>,
#  <keras.engine.input_layer.InputLayer at 0x7f986069c080>,
#  <keras.engine.input_layer.InputLayer at 0x7f98605dd9b0>,
#  <keras.engine.input_layer.InputLayer at 0x7f98605dfdd8>,
#  <keras.feature_column.dense_features_v2.DenseFeatures at 0x7f9861ff1f28>,
#  <keras.layers.core.dense.Dense at 0x7f983bb3a780>,
#  <keras.layers.core.dropout.Dropout at 0x7f983bb2ab70>,
#  <keras.layers.core.dense.Dense at 0x7f983bb2a128>,
#  <keras.layers.core.dropout.Dropout at 0x7f983bb1b748>,
#  <keras.feature_column.dense_features_v2.DenseFeatures at 0x7f983bb1b550>,
#  <keras.layers.merge.Concatenate at 0x7f983bb0ff28>,
#  <keras.layers.core.dense.Dense at 0x7f983bbfff98>,
#  <keras.layers.core.tf_op_layer.TFOpLambda at 0x7f983bbffc88>,
#  <keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer at 0x7f983bbff048>]

# %%
model_run_dir = trainer.outputs['model'].get()[0].uri
model_run_dir
# Out:
# './pipeline/Trainer/model/227'

# %%
model = trainer.outputs['model']

# %%
new_model2 = tf.keras.models.load_model(f"{model_run_dir}/Format-Serving")
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f983a9cb198> and <keras.engine.input_layer.InputLayer object at 0x7f983aa73f98>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f983a9cb198> and <keras.engine.input_layer.InputLayer object at 0x7f983aa73f98>).

# %%
new_model2.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x7f983aa73f98>,
#  <keras.engine.input_layer.InputLayer at 0x7f983aa7c128>,
#  <keras.engine.input_layer.InputLayer at 0x7f983aa7ce10>,
#  <keras.engine.input_layer.InputLayer at 0x7f983aa11908>,
#  <keras.engine.input_layer.InputLayer at 0x7f983aa11438>,
#  <keras.engine.input_layer.InputLayer at 0x7f986820a748>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9df588>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9dfb00>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e10b8>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e1630>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e1ba8>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e4160>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e46d8>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e4c50>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e9208>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e9780>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9e9cf8>,
#  <keras.engine.input_layer.InputLayer at 0x7f983a9ef2e8>,
#  <keras.engine.functional.Functional at 0x7f983a9ef518>,
#  <keras.feature_column.dense_features_v2.DenseFeatures at 0x7f983aa73eb8>,
#  <keras.layers.merge.Concatenate at 0x7f983a9c46d8>,
#  <keras.layers.core.dense.Dense at 0x7f983a9c4ba8>,
#  <keras.layers.core.tf_op_layer.TFOpLambda at 0x7f983a9c4f98>,
#  <keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer at 0x7f983a9cb198>]

# %%
model=trainer.outputs['model']

# %%
import tensorflow as tf
new_model = tf.keras.models.load_model(f"{model_run_dir}/Format-Serving")
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f9d08cf9358> and <keras.engine.input_layer.InputLayer object at 0x7f9d6fb83d68>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7f9d08cf9358> and <keras.engine.input_layer.InputLayer object at 0x7f9d6fb83d68>).

# %%
new_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  audience_id (InputLayer)       [(None,)]            0           []
#
#  device_type (InputLayer)       [(None,)]            0           []
#
#  nb_clicks_1week (InputLayer)   [(None,)]            0           []
#
#  partner_id (InputLayer)        [(None,)]            0           []
#
#  product_age_group (InputLayer)  [(None,)]           0           []
#
#  product_brand (InputLayer)     [(None,)]            0           []
#
#  product_category1 (InputLayer)  [(None,)]           0           []
#
#  product_category2 (InputLayer)  [(None,)]           0           []
#
#  product_category3 (InputLayer)  [(None,)]           0           []
#
#  product_category4 (InputLayer)  [(None,)]           0           []
#
#  product_category5 (InputLayer)  [(None,)]           0           []
#
#  product_category6 (InputLayer)  [(None,)]           0           []
#
#  product_category7 (InputLayer)  [(None,)]           0           []
#
#  product_country (InputLayer)   [(None,)]            0           []
#
#  product_gender (InputLayer)    [(None,)]            0           []
#
#  product_id (InputLayer)        [(None,)]            0           []
#
#  product_title (InputLayer)     [(None,)]            0           []
#
#  user_id (InputLayer)           [(None,)]            0           []
#
#  dense_features_7 (DenseFeature  (None, 1)           0           ['audience_id[0][0]',
#  s)                                                               'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  dense_10 (Dense)               (None, 40)           80          ['dense_features_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 40)           0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 70)           2870        ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 70)           0           ['dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 100)          7100        ['dropout_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 100)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 80)           8080        ['dropout_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 80)           0           ['dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 30)           2430        ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 30)           0           ['dense_14[0][0]']
#
#  dense_features_8 (DenseFeature  (None, 17017)       0           ['audience_id[0][0]',
#  s)                                                               'device_type[0][0]',
#                                                                   'nb_clicks_1week[0][0]',
#                                                                   'partner_id[0][0]',
#                                                                   'product_age_group[0][0]',
#                                                                   'product_brand[0][0]',
#                                                                   'product_category1[0][0]',
#                                                                   'product_category2[0][0]',
#                                                                   'product_category3[0][0]',
#                                                                   'product_category4[0][0]',
#                                                                   'product_category5[0][0]',
#                                                                   'product_category6[0][0]',
#                                                                   'product_category7[0][0]',
#                                                                   'product_country[0][0]',
#                                                                   'product_gender[0][0]',
#                                                                   'product_id[0][0]',
#                                                                   'product_title[0][0]',
#                                                                   'user_id[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 17047)        0           ['dropout_8[0][0]',
#                                                                   'dense_features_8[0][0]']
#
#  dense_15 (Dense)               (None, 1)            17048       ['concatenate_6[0][0]']
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None,)             0           ['dense_15[0][0]']
#  mbda)
#
#  transform_features_layer_2 (Te  multiple            0           []
#  nsorFlowTransform>TransformFea
#  turesLayer)
#
# ==================================================================================================
# Total params: 37,608
# Trainable params: 37,608
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_resolver = resolver.Resolver(
      strategy_class=latest_blessed_model_resolver.LatestBlessedModelResolver,
      model=Channel(type=Model),
      model_blessing=Channel(
          type=ModelBlessing)).with_id('latest_blessed_model_resolver')

# %%
context.run(model_resolver)
# Out:
# ExecutionResult(
#     component_id: latest_blessed_model_resolver
#     execution_id: 247
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: [Artifact(artifact: id: 524
#         type_id: 25
#         uri: "./pipeline/Trainer/model/242"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         create_time_since_epoch: 1645880983530
#         last_update_time_since_epoch: 1645883286047
#         , artifact_type: id: 25
#         name: "Model"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_blessing: Channel(
#             type_name: ModelBlessing
#             artifacts: [Artifact(artifact: id: 529
#         type_id: 33
#         uri: "./pipeline/Evaluator/blessing/245"
#         custom_properties {
#           key: "blessed"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "current_model"
#           value {
#             string_value: "./pipeline/Trainer/model/242"
#           }
#         }
#         custom_properties {
#           key: "current_model_id"
#           value {
#             int_value: 524
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "blessing"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Evaluator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         create_time_since_epoch: 1645883632926
#         last_update_time_since_epoch: 1645883885930
#         , artifact_type: id: 33
#         name: "ModelBlessing"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
eval_config = tfma.EvalConfig(
      model_specs=[
          tfma.ModelSpec(
              signature_name='serving_default', label_key='Sale',
              preprocessing_function_names=['transform_features'])
      ],
      slicing_specs=[tfma.SlicingSpec()],
      metrics_specs=[
          tfma.MetricsSpec(metrics=[
              tfma.MetricConfig(
                  class_name='AUC',
                  threshold=tfma.MetricThreshold(
                      value_threshold=tfma.GenericValueThreshold(
                          lower_bound={'value': 0.7}),
                     
                      change_threshold=tfma.GenericChangeThreshold(
                          direction=tfma.MetricDirection.HIGHER_IS_BETTER,
                          absolute={'value': -1e-10})))
          ])
      ])
evaluator = Evaluator(
      examples=example_gen.outputs['examples'],
      model=trainer.outputs['model'],
      baseline_model=model_resolver.outputs['model'],
      # Change threshold will be ignored if there is no baseline (first run).
      eval_config=eval_config)
context.run(evaluator)
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa42018c1d0> and <keras.engine.input_layer.InputLayer object at 0x7fa4211f4ac8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa42018c1d0> and <keras.engine.input_layer.InputLayer object at 0x7fa4211f4ac8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa444b52d68> and <keras.engine.input_layer.InputLayer object at 0x7fa4211d0dd8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa444b52d68> and <keras.engine.input_layer.InputLayer object at 0x7fa4211d0dd8>).
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa4058dd7b8> and <keras.engine.input_layer.InputLayer object at 0x7fa40d9f5ba8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa4058dd7b8> and <keras.engine.input_layer.InputLayer object at 0x7fa40d9f5ba8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3eddba940> and <keras.engine.input_layer.InputLayer object at 0x7fa3edd09ef0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3eddba940> and <keras.engine.input_layer.InputLayer object at 0x7fa3edd09ef0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3d1f6d358> and <keras.engine.input_layer.InputLayer object at 0x7fa3d1e018d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3d1f6d358> and <keras.engine.input_layer.InputLayer object at 0x7fa3d1e018d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa407ab8128> and <keras.engine.input_layer.InputLayer object at 0x7fa4202079b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa407ab8128> and <keras.engine.input_layer.InputLayer object at 0x7fa4202079b0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3cc939898> and <keras.engine.input_layer.InputLayer object at 0x7fa3cc8c52e8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3cc939898> and <keras.engine.input_layer.InputLayer object at 0x7fa3cc8c52e8>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3bf03c320> and <keras.engine.input_layer.InputLayer object at 0x7fa3befb88d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x7fa3bf03c320> and <keras.engine.input_layer.InputLayer object at 0x7fa3befb88d0>).
# WARNING:tensorflow:From /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:109: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/tensorflow_model_analysis/writers/metrics_plots_and_validations_writer.py:109: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 245
#     outputs:
#         evaluation: Channel(
#             type_name: ModelEvaluation
#             artifacts: [Artifact(artifact: id: 528
#         type_id: 32
#         uri: "./pipeline/Evaluator/evaluation/245"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "evaluation"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Evaluator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 32
#         name: "ModelEvaluation"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         blessing: Channel(
#             type_name: ModelBlessing
#             artifacts: [Artifact(artifact: id: 529
#         type_id: 33
#         uri: "./pipeline/Evaluator/blessing/245"
#         custom_properties {
#           key: "blessed"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "current_model"
#           value {
#             string_value: "./pipeline/Trainer/model/242"
#           }
#         }
#         custom_properties {
#           key: "current_model_id"
#           value {
#             int_value: 524
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "blessing"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Evaluator"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 33
#         name: "ModelBlessing"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
context.show(evaluator.outputs['evaluation'])
# Out:
# <b>Artifact at ./pipeline/Evaluator/evaluation/245</b><br/><br/>

# %%
pusher = Pusher(
      model=trainer.outputs['model'],
      model_blessing=evaluator.outputs['blessing'],
      push_destination=pusher_pb2.PushDestination(
          filesystem=pusher_pb2.PushDestination.Filesystem(
              base_directory='./pipeline')))

# %%
context.run(pusher)
# Out:
# ExecutionResult(
#     component_id: Pusher
#     execution_id: 246
#     outputs:
#         pushed_model: Channel(
#             type_name: PushedModel
#             artifacts: [Artifact(artifact: id: 530
#         type_id: 35
#         uri: "./pipeline/Pusher/pushed_model/246"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pushed_model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Pusher"
#           }
#         }
#         custom_properties {
#           key: "pushed"
#           value {
#             int_value: 1
#           }
#         }
#         custom_properties {
#           key: "pushed_destination"
#           value {
#             string_value: "./pipeline/1645884348"
#           }
#         }
#         custom_properties {
#           key: "pushed_version"
#           value {
#             string_value: "1645884348"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.6.1"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 35
#         name: "PushedModel"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
df = pd.read_csv("./data/criteo/data3/data3.csv")
# Out:
# /home/alireza/Desktop/MLOps/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (300000, 24)
